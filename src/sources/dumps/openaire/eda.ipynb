# %% [markdown]
# # OpenAire raw EDA
#
# ## Setup

# %%
import sys
sys.path.insert(0, '/home/lu72hip/DIGICHer/dh_pipeline/src')
import pandas as pd
from pathlib import Path
from lib.database.duck.create_connection import create_duck_connection
from utils.config.config_loader import get_query_config

config = get_query_config()['openaire_dump']
# DB = Path(config['path_duck'])
DB = Path(config["path_duck_staging"])

con = create_duck_connection(str(DB))
con.execute("SET memory_limit='64GB'")
con.execute("SET threads=16")
print(f'Connected to {DB}')

pd.set_option("display.max_rows", 21) # Show more rows  # or None for unlimited
pd.set_option("display.max_columns", None) # Show more columns  # None = show all
# pd.set_option("display.max_colwidth", None) # Don't truncate column content  # None = full content
# pd.set_option("display.width", None) # Wider display  # Auto-detect terminal width
# Out:
# /home/lu72hip/DIGICHer/dh_pipeline/config/config_queries.json {'arxiv': {'checkpoint': 'submittedDateTo', 'queries': [{'query': '(all:cultural+OR+all:heritage+OR+all:digital+OR+all:humanities)', 'download_attachments': True, 'checkpoint_start': '1990-01-01-00-00', 'checkpoint_range': '6'}, {'query': 'all:computing+AND+(all:humanities+OR+all:heritage)', 'download_attachments': True, 'checkpoint_start': '1990-01-01-00-00', 'checkpoint_range': '6'}]}, 'cordis': {'checkpoint': 'startDate', 'queries': [{'query': 'cultural OR heritage OR digital OR humanities', 'download_attachments': True, 'checkpoint_start': '1985-01-01', 'checkpoint_range': '1'}, {'query': "contenttype='project' AND '*'", 'download_attachments': False, 'checkpoint_start': '1985-01-01', 'checkpoint_range': '1', 'path_duck': '/work/lu72hip/data/duckdb/sources/cordis_raw.duckdb'}]}, 'coreac': {'checkpoint': 'publishedDate', 'queries': [{'query': '((computing AND cultural) OR (computing AND heritage))', 'download_attachments': False, 'checkpoint_start': '1990-01-01', 'checkpoint_range': '10'}]}, 'openaire': {'checkpoint': 'startYear', 'queries': [{'query': 'cultural', 'download_attachments': False, 'checkpoint_start': '1957', 'checkpoint_range': '1'}, {'query': 'heritage', 'download_attachments': False, 'checkpoint_start': '1957', 'checkpoint_range': '1'}, {'query': 'digital', 'download_attachments': False, 'checkpoint_start': '1957', 'checkpoint_range': '1'}, {'query': 'humanities', 'download_attachments': False, 'checkpoint_start': '1957', 'checkpoint_range': '1'}]}, 'meta_heritage': {'checkpoint': None}, 'openaire_dump': {'path_raw': '/work/lu72hip/data/pile/openaire_2025_12_01_dump', 'path_duck': '/work/lu72hip/data/duckdb/sources/openaire_raw.duckdb', 'path_duck_staging': '/work/lu72hip/data/duckdb/sources/openaire_staging.duckdb'}, 'openalex_dump': {'path_raw': '/work/lu72hip/data/pile/openalex_2026_02_03_dump', 'path_duck': '/work/lu72hip/data/duckdb/sources/openalex_raw.duckdb'}, 'ror_dump': {'path_raw': '/work/lu72hip/data/pile/ror_2026_02_24_dump/v2.3-2026-02-24-ror-data.json', 'path_duck': '/work/lu72hip/data/duckdb/sources/ror_raw.duckdb'}, 'core_v3': {'path_duck': '/work/lu72hip/data/duckdb/core/core_v3.duckdb'}}
# Connected to /work/lu72hip/data/duckdb/sources/openaire_staging.duckdb

# %% [markdown]
# ## General Stats

# %%
### Get counts of all tables

q = """ 
SELECT
    table_name,
    estimated_size as cnt
FROM duckdb_tables()
WHERE schema_name = 'main'
ORDER BY estimated_size DESC
"""
con.execute(q).df()
# Out:
#      table_name        cnt
# 0      relation  562206510
# 1          work  205841448
# 2       project    3656773
# 3  organization     448161

# %%
### Hash duplication detection
# Result: No collisions :)

q = """
SELECT 
    COUNT(*) as total_rows,
    COUNT(DISTINCT id) as unique_ids,
    COUNT(DISTINCT hash(id)) as unique_hashes,
    total_rows - unique_hashes as collisions
FROM work
"""
display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    total_rows  unique_ids  unique_hashes  collisions
# 0   205841448   205841448      205841448           0

# %% [markdown]
# ## Entity Organization
#
# ### Geolocation
#
# * 440k orgs in total
# * 120k ROR orgs
# --> For Beta only get geolocations for ROR
#
# * GRID
# * PIC 70342
# * ISNI 60138
# * Wikidata 57673 -> ROR overlap
# * mag_id 27080
# * FundRef 22750
# * OrgRef 16448
# * RNSR 9157
# * OrgReg 6639
# --> After BETA calculate overlap of other schemas with ROR, see if u can get geolocations from scheme source
# --> For remaining orgs use Geocoding services with name + country
#
# ### Sanitization Organization
#
# * legalName: Asc and Desc -> Good, but needs legalName sanitization
# * BOM needs to be cleaned in text, eg value.lstrip('\ufeff\u200b\u200c\u200d\ufffe')

# %%
###  Sample Rows

q = """ 
SELECT * FROM organization o
LIMIT 3;
"""
display(con.execute(q).df())
# Out:
#                      id                                      openaireId  \
# 0   1934433190169772723  openorgs____::05a9c3805e5e7d8933851bf80982e400
# 1  16526272328665692646  openorgs____::14661c2b103c69736d711c1ca49c0602
# 2     40960094163156804  openorgs____::1c063fea076f9fd2dbfd87faf906c647
#
#                                legalName legalShortName  \
# 0              BONFIGLIOLI RIDUTTORI SPA            BRI
# 1         Mid Michigan Community College           MMCC
# 2  International Fund for Animal Welfare           IFAW
#
#                           websiteUrl  \
# 0         http://www.bonfiglioli.com
# 1           https://www.midmich.edu/
# 2  http://www.ifaw.org/united-states
#
#                                 alternativeNames countryCode  \
# 0                                          [BRI]          IT
# 1         [Mid Michigan Community College, MMCC]          US
# 2  [International Fund for Animal Welfare, IFAW]          US
#
#                        rorId    wikiId
# 0                       None      None
# 1  https://ror.org/03f3r3r28  Q6840980
# 2  https://ror.org/043c66817  Q1666594

# %%
### How often each Oragnization ID scheme is used across all orgs

q = """ 
SELECT 
    pid.scheme,
    COUNT(DISTINCT organization.id) as orgs_with_scheme,
    ROUND(100.0 * COUNT(DISTINCT organization.id) / (SELECT COUNT(*) FROM organization), 2) as pct_coverage
FROM organization,
UNNEST(pids) as t(pid)
GROUP BY pid.scheme
ORDER BY orgs_with_scheme DESC
"""
display(con.execute(q).df())
# Out:
#       scheme  orgs_with_scheme  pct_coverage
# 0        ROR            123542         27.57
# 1       GRID            108191         24.14
# 2        PIC             69287         15.46
# 3       ISNI             59194         13.21
# 4   Wikidata             56164         12.53
# 5     mag_id             26448          5.90
# 6    FundRef             17919          4.00
# 7     OrgRef             15148          3.38
# 8     OrgReg              6477          1.45
# 9       RNSR              6412          1.43
# 10      CNRS               846          0.19
# 11      RRID               670          0.15
# 12       CVR               198          0.04
# 13     UKPRN               175          0.04
# 14      HESA               173          0.04
# 15      UCAS               153          0.03
# 16      VIAF                92          0.02
# 17  RingGold                56          0.01
# 18  LinkedIn                10          0.00
# 19       NIF                 4          0.00
# 20     DGEEC                 2          0.00

# %%
### Search FSU Jena

q = """ 
SELECT * FROM organization o
WHERE legalName like '%Schiller%'
AND legalShortName = 'FSU'
ORDER BY legalName DESC
LIMIT 2
"""
display(con.execute(q).df())
# Out:
#   legalShortName                           legalName  \
# 0            FSU  Friedrich Schiller University Jena
#
#                               websiteUrl  \
# 0  https://www.uni-jena.de/en/start.html
#
#                                     alternativeNames  \
# 0  [Friedrich-Schiller-Universität Jena, Friedric...
#
#                               country  \
# 0  {'code': 'DE', 'label': 'Germany'}
#
#                                                id  \
# 0  openorgs____::f729b2897d3163c51a6fd5c9867c6dce
#
#                                                 pids
# 0  [{'scheme': 'ISNI', 'value': '0000000119392794...

# %%
### Sanitization: legalName
# * Needs to trim BOM

q = """ 
SELECT legalName FROM organization o
ORDER BY TRIM(REPLACE(legalName, chr(65279), '')) DESC -- 65279 = BOM
LIMIT 30;
"""
display(con.execute(q).df())
# Out:
#                              legalName
# 0                     中粮工科（西安）国际工程有限公司
# 1                        上海交通大学出版社有限公司
# 2                           《光通信研究》编辑部
# 3                            《中国油脂》杂志社
# 4
# Energy Dynamics (Norway)
# ..                                 ...
# 25  ​The Chinese Physiological Society
# 26               ​Sevalanka Foundation
# 27              ​Mercy College of Ohio
# 28                    ​Hail University
# 29            ​Eicosis (United States)
#
# [30 rows x 1 columns]

# %%
### Check legalName duplicates ###

q = """ 
SELECT legalName, country, COUNT(*) as cnt
FROM organization 
GROUP BY legalName, country
HAVING COUNT(*) > 1
ORDER BY cnt DESC"""
# display(con.execute(q).df())

### Same name 'Ministry of Health' for different countries ###

q = """ 
SELECT * FROM organization 
WHERE legalName = 'Ministry of Health'"""
# display(con.execute(q).df())

### See ROR specific duplicates ###

q = """ 
SELECT legalName, country, COUNT(*) as cnt
FROM organization 
WHERE list_contains(list_transform(pids, x -> x.scheme), 'ROR')
GROUP BY legalName, country
HAVING COUNT(*) > 1
ORDER BY cnt DESC
"""
# display(con.execute(q).df())

### Check Argosy University entries for duplicates in ROR
# * All 17 are subsidiaries/ departments of the same institution in different regions -> no dup

q = """
SELECT 
    id,
    legalName,
    legalShortName,
    websiteUrl,
    country,
    alternativeNames,
    pids
FROM organization 
WHERE legalName = 'Argosy University' 
  AND country.code = 'US'
  AND list_contains(list_transform(pids, x -> x.scheme), 'ROR')
ORDER BY id
"""
display(con.execute(q).df())
# Out:
#                                                 id          legalName  \
# 0   openorgs____::3dec1dbb744beb8db085730d02cb62bd  Argosy University
# 1   pending_org_::103e41938ad592409b0b322d0a8c0cb0  Argosy University
# 2   pending_org_::198d821956d4a7b3b6a8ed9e160320d7  Argosy University
# 3   pending_org_::2c171a84133bdef229f2473a2a2a24a5  Argosy University
# 4   pending_org_::308a7ce1dbcadad2d5fcc3c285497662  Argosy University
# 5   pending_org_::3b604a19267967081c2c316842d2a4c3  Argosy University
# 6   pending_org_::5ab843685c0380cb4230b59bc8ad130d  Argosy University
# 7   pending_org_::6b3ca500ae14ce05558d33e83f1e4318  Argosy University
# 8   pending_org_::8258f6d5ca447f27b3ef3a9d93f3cc9f  Argosy University
# 9   pending_org_::835a06a4c5cf1dcb0765ab0385201088  Argosy University
# 10  pending_org_::859db0340b0d31f85f1a54d0795ce214  Argosy University
# 11  pending_org_::85b7c8e62a6a9eeca1bce049a66c3418  Argosy University
# 12  pending_org_::8c97ed9f343ff2106a1d6d05bcd4d20b  Argosy University
# 13  pending_org_::a9d7b6d8196d4b7d31a6f1f4085c3000  Argosy University
# 14  pending_org_::b30daf78f8cd20d549350f776ba58269  Argosy University
# 15  pending_org_::bbdf87c3958201d7089702442bc21e6d  Argosy University
# 16  pending_org_::c365d6a9c57f99081330bf5f377400e7  Argosy University
#
#        legalShortName                                         websiteUrl  \
# 0   Argosy University                            https://www.argosy.edu/
# 1   Argosy University         https://www.argosy.edu/locations/nashville
# 2   Argosy University  https://www.argosy.edu/locations/chicago-downtown
# 3   Argosy University  https://www.argosy.edu/locations/chicago-schau...
# 4   Argosy University                                 http://argosy.edu/
# 5   Argosy University            https://www.argosy.edu/locations/hawaii
# 6   Argosy University            https://www.argosy.edu/locations/dallas
# 7   Argosy University           https://www.argosy.edu/locations/atlanta
# 8   Argosy University                   https://www.argosy.edu/fullerton
# 9   Argosy University             https://www.argosy.edu/locations/tampa
# 10  Argosy University     https://www.argosy.edu/locations/inland-empire
# 11  Argosy University           https://www.argosy.edu/locations/phoenix
# 12  Argosy University    https://www.argosy.edu/locations/salt-lake-city
# 13  Argosy University       https://www.argosy.edu/locations/los-angeles
# 14  Argosy University     https://www.argosy.edu/locations/san-francisco
# 15  Argosy University          https://www.argosy.edu/locations/sarasota
# 16  Argosy University            https://www.argosy.edu/locations/denver
#
#                                      country     alternativeNames  \
# 0   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 1   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 2   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 3   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 4   {'code': 'US', 'label': 'United States'}                 <NA>
# 5   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 6   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 7   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 8   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 9   {'code': 'US', 'label': 'United States'}  [Argosy University]
# 10  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 11  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 12  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 13  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 14  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 15  {'code': 'US', 'label': 'United States'}  [Argosy University]
# 16  {'code': 'US', 'label': 'United States'}  [Argosy University]
#
#                                                  pids
# 0   [{'scheme': 'GRID', 'value': 'grid.441437.1'},...
# 1   [{'scheme': 'GRID', 'value': 'grid.472245.2'},...
# 2   [{'scheme': 'OrgRef', 'value': '5899363'}, {'s...
# 3   [{'scheme': 'GRID', 'value': 'grid.441454.4'},...
# 4   [{'scheme': 'ISNI', 'value': '000000040389111X...
# 5   [{'scheme': 'ISNI', 'value': '0000000403890715...
# 6   [{'scheme': 'Wikidata', 'value': 'Q30293684'},...
# 7   [{'scheme': 'ROR', 'value': 'https://ror.org/0...
# 8   [{'scheme': 'GRID', 'value': 'grid.466460.6'},...
# 9   [{'scheme': 'GRID', 'value': 'grid.472247.0'},...
# 10  [{'scheme': 'ISNI', 'value': '0000000403988923...
# 11  [{'scheme': 'ROR', 'value': 'https://ror.org/0...
# 12  [{'scheme': 'GRID', 'value': 'grid.472246.1'},...
# 13  [{'scheme': 'ISNI', 'value': '0000000406094773...
# 14  [{'scheme': 'ROR', 'value': 'https://ror.org/0...
# 15  [{'scheme': 'ISNI', 'value': '0000000403890977...
# 16  [{'scheme': 'GRID', 'value': 'grid.441038.a'},...

# %% [markdown]
# ## Entity Project

# %%
### Sample Rows
# 226 publications with title 'unidentified'
# 16587 with title NULL and 'unidentified'

q = """ 
SELECT * FROM project
WHERE array_length(frameworkProgrammes) > 0
LIMIT 3
"""
display(con.execute(q).df())

### Look at specific columns
q = """ 
SELECT title, granted FROM project
WHERE granted is not NULL
LIMIT 15
"""
# display(con.execute(q).df())
# Out:
#                      id                                      openaireId  \
# 0  16508330868004209722  arc_________::017f6ae69fd53f561c2a6fadca03357a
# 1  12618460875906795443  arc_________::01d40223496c2bb9652fcb3136c51209
# 2  12189159823196739702  arc_________::01e131e2f08b7eea5ff63c060307a8dd
#
#        grantId                                              title acronym  \
# 0    DP0451399  Understanding the structure of internal migrat...    None
# 1  DP200100475         Discovery Projects - Grant ID: DP200100475    None
# 2  DP140101565         Discovery Projects - Grant ID: DP140101565    None
#
#                                           websiteUrl  startDate    endDate  \
# 0   http://purl.org/au-research/grants/arc/DP0451399 2004-01-01 2008-12-31
# 1  http://purl.org/au-research/grants/arc/DP20010... 2020-01-01 2023-12-31
# 2  http://purl.org/au-research/grants/arc/DP14010... 2014-01-01 2018-12-31
#
#   callIdentifier keywords  openAccessMandateForPublications  \
# 0           None     None                             False
# 1           None     None                             False
# 2           None     None                             False
#
#    openAccessMandateForDataset subjects  \
# 0                        False     <NA>
# 1                        False     <NA>
# 2                        False     <NA>
#
#                                             fundings   frameworkProgrammes  \
# 0  [{'shortName': 'ARC', 'name': 'Australian Rese...  [Discovery Projects]
# 1  [{'shortName': 'ARC', 'name': 'Australian Rese...  [Discovery Projects]
# 2  [{'shortName': 'ARC', 'name': 'Australian Rese...  [Discovery Projects]
#
#                                              summary  \
# 0  Understanding the structure of internal migrat...
# 1  Caveospheres: A versatile peptide delivery sys...
# 2  Pushing The Boundaries Of Flow Chemistry &#821...
#
#                                              granted
# 0  {'currency': 'AUD', 'totalCost': 0.0, 'fundedA...
# 1  {'currency': 'AUD', 'totalCost': 0.0, 'fundedA...
# 2  {'currency': 'AUD', 'totalCost': 0.0, 'fundedA...

# %%
### Project Table: Null/Empty Analysis ###

q = """
SELECT 
    'id' as column_name,
    COUNT(*) - COUNT(id) as null_count,
    ROUND(100.0 * (COUNT(*) - COUNT(id)) / COUNT(*), 2) as null_pct
FROM project
UNION ALL
SELECT 
    'code',
    COUNT(*) - COUNT(code),
    ROUND(100.0 * (COUNT(*) - COUNT(code)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'acronym',
    COUNT(*) - COUNT(acronym),
    ROUND(100.0 * (COUNT(*) - COUNT(acronym)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'title',
    COUNT(*) - COUNT(title),
    ROUND(100.0 * (COUNT(*) - COUNT(title)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'websiteUrl',
    COUNT(*) - COUNT(websiteUrl),
    ROUND(100.0 * (COUNT(*) - COUNT(websiteUrl)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'startDate',
    COUNT(*) - COUNT(startDate),
    ROUND(100.0 * (COUNT(*) - COUNT(startDate)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'endDate',
    COUNT(*) - COUNT(endDate),
    ROUND(100.0 * (COUNT(*) - COUNT(endDate)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'callIdentifier',
    COUNT(*) - COUNT(callIdentifier),
    ROUND(100.0 * (COUNT(*) - COUNT(callIdentifier)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'keywords',
    COUNT(*) - COUNT(keywords),
    ROUND(100.0 * (COUNT(*) - COUNT(keywords)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'openAccessMandateForPublications',
    COUNT(*) - COUNT(openAccessMandateForPublications),
    ROUND(100.0 * (COUNT(*) - COUNT(openAccessMandateForPublications)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'openAccessMandateForDataset',
    COUNT(*) - COUNT(openAccessMandateForDataset),
    ROUND(100.0 * (COUNT(*) - COUNT(openAccessMandateForDataset)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'subjects',
    COUNT(*) - COUNT(subjects),
    ROUND(100.0 * (COUNT(*) - COUNT(subjects)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'fundings',
    COUNT(*) - COUNT(fundings),
    ROUND(100.0 * (COUNT(*) - COUNT(fundings)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'summary',
    COUNT(*) - COUNT(summary),
    ROUND(100.0 * (COUNT(*) - COUNT(summary)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'granted',
    COUNT(*) - COUNT(granted),
    ROUND(100.0 * (COUNT(*) - COUNT(granted)) / COUNT(*), 2)
FROM project
UNION ALL
SELECT 
    'h2020Programmes',
    COUNT(*) - COUNT(h2020Programmes),
    ROUND(100.0 * (COUNT(*) - COUNT(h2020Programmes)) / COUNT(*), 2)
FROM project
ORDER BY null_count DESC
"""
display(con.execute(q).df())

# %%
### Filter EC as funder
q = """ 
SELECT 
    title, 
    unnest(fundings) as funding
FROM project
WHERE list_contains(
    list_transform(fundings, f -> f.shortName), 
    'EC'
)
LIMIT 3
"""
display(con.execute(q).df())

### Count Projects funded by EC
# Result: 115447

q = """
SELECT COUNT(DISTINCT id) AS ec_project_count
FROM project
WHERE list_contains(
    list_transform(fundings, f -> f.shortName),
    'EC'
);
"""
display(con.execute(q).df())
# Out:
#                                                title  \
# 0  Design, analysis and applications of novel inf...
# 1  Functional and molecular characterization of e...
# 2  Production of Coatings for New Efficient and C...
#
#                                              funding
# 0  {'shortName': 'EC', 'name': 'European Commissi...
# 1  {'shortName': 'EC', 'name': 'European Commissi...
# 2  {'shortName': 'EC', 'name': 'European Commissi...
#    ec_project_count
# 0            115447

# %%
### Extract EU frameworkProgrammes
# Result| EC :: {FRAMEWORK} :: {CALL_TYPE}

q = """
SELECT DISTINCT 
    unnest(list_transform(fundings, f -> f.fundingStream.id)) as funding_stream_id
FROM project
WHERE list_contains(
    list_transform(fundings, f -> f.shortName), 
    'EC'
)
LIMIT 20
"""
display(con.execute(q).df())
# Out:
#                                     funding_stream_id
# 0                      EC::HE::HORIZON-EIC\HORIZON-AG
# 1                                    EC::H2020::SME-1
# 2                               EC::H2020::MSCA-IF-GF
# 3                               EC::FP7::SP4::REGIONS
# 4                                   EC::FP7::SP1::SSH
# 5                                   EC::FP7::SP1::SPA
# 6                          EC::HE::HORIZON-EIC-ACC-BF
# 7                                 EC::HE::EURATOM-RIA
# 8                               EC::HE::HORIZON-JU-IA
# 9                                       EC::H2020::IA
# 10                            EC::H2020::ERC::ERC-ADG
# 11                                 EC::H2020::BBI-CSA
# 12                                 EC::H2020::BBI-RIA
# 13  EC::ERASMUS+::Cooperation for innovation and t...
# 14  EC::ERASMUS+::Cooperation for innovation and t...
# 15  EC::ERASMUS+::Partnerships for cooperation and...
# 16                                  EC::FP7::SP1::ICT
# 17                                            EC::FP7
# 18                                   EC::H2020::SME-2
# 19                                          EC::H2020

# %%
### How to extract FPs from EC Projects

q = """
CREATE TABLE projects_clean AS
SELECT 
    hash(id) as id,
    id as openaire_id,
    title,
    summary,
    callIdentifier as call_identifier,
    
    -- Extract EU framework from fundingStream.id
    -- Split by '::' and take the 2nd element
    CASE 
        WHEN list_contains(
            list_transform(fundings, f -> f.shortName), 
            'EC'
        ) THEN (
            SELECT string_split(
                list_filter(
                    list_transform(fundings, f -> f.fundingStream.id),
                    x -> x LIKE 'EC::%'
                )[1],  -- first EC funding stream
                '::'
            )[2]  -- second segment = framework
        )
        ELSE NULL
    END as eu_framework,
    
    -- Keep full fundings
    fundings,
    
    -- other columns...
FROM project
"""
q = "select * from projects_clean where eu_framework is not null limit 10"
# display(con.execute(q).df())

# %%
### For each PID scheme (ROR, GRID etc.), how many projects connect to orgs with that scheme?
#
# 2658616 without scheme

### With scheme
q = """ 
WITH project_schemes AS (
    SELECT DISTINCT 
        p.id AS project_id,
        op.scheme
    FROM project p
    JOIN relation r 
        ON r.source = p.id 
        AND r.sourceType = 'project'
        AND r.relType.type = 'participation'
    JOIN organization o 
        ON r.target = o.id 
        AND r.targetType = 'organization'
    JOIN organization_pids op 
        ON op.org_id = o.id
)
SELECT 
    scheme,
    COUNT(DISTINCT project_id) AS projects_count
FROM project_schemes
GROUP BY scheme
ORDER BY projects_count DESC;
"""
display(con.execute(q).df())

### Schemeless
q = """ 
WITH project_schemes AS (
    SELECT DISTINCT p.id AS project_id
    FROM project p
    JOIN relation r 
        ON r.source = p.id 
        AND r.sourceType = 'project'
        AND r.relType.type = 'participation'
    JOIN organization o 
        ON r.target = o.id 
        AND r.targetType = 'organization'
    JOIN organization_pids op 
        ON op.org_id = o.id
)
SELECT COUNT(*) AS schemeless_projects
FROM project p
WHERE p.id NOT IN (SELECT project_id FROM project_schemes);
"""
display(con.execute(q).df())
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[16], line 29
#       1 ### For each PID scheme (ROR, GRID etc.), how many projects connect to orgs with that scheme?
#       2 #
#       3 # 2658616 without scheme
#       4
#       5 ### With scheme
#       6 q = """
#       7 WITH project_schemes AS (
#       8     SELECT DISTINCT
#    (...)     27 ORDER BY projects_count DESC;
#      28 """
# ---> 29 display(con.execute(q).df())
#      31 ### Schemeless
#      32 q = """
#      33 WITH project_schemes AS (
#      34     SELECT DISTINCT p.id AS project_id
#    (...)     48 WHERE p.id NOT IN (SELECT project_id FROM project_schemes);
#      49 """
#
# CatalogException: Catalog Error: Table with name organization_pids does not exist!
# Did you mean "organization"?
#
# LINE 14:     JOIN organization_pids op
#                   ^

# %%
### What types of project→org relationships exist?
# Result: No distinction between coordinator / participant

q = """ 
SELECT 
    r.relType.type,
    r.relType.name,
    COUNT(*) as count,
    COUNT(DISTINCT r.source) as unique_projects,
    COUNT(DISTINCT r.target) as unique_orgs
FROM relation r
WHERE r.sourceType = 'project' 
  AND r.targetType = 'organization'
GROUP BY r.relType.type, r.relType.name
ORDER BY count DESC;
"""
display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#             type            name    count  unique_projects  unique_orgs
# 0  participation  hasParticipant  4568712          3372450       309580

# %%
### Date range sanity check: low and high years in project and publication dates
# We need to sanitize: year < 1000 AND or also > 3000

q = """                                                                                                                                        
SELECT 'project.startDate' AS col, MIN(year(startDate)) AS min_year, MAX(year(startDate)) AS max_year,                                         
    COUNT(*) FILTER (WHERE year(startDate) < 1000) AS below_1000,                                                                              
    COUNT(*) FILTER (WHERE year(startDate) > 3000) AS above_3000                                                                               
FROM project WHERE startDate IS NOT NULL                                                                                                       
UNION ALL                                                                                                                                      
SELECT 'project.endDate', MIN(year(endDate)), MAX(year(endDate)),                                                                              
    COUNT(*) FILTER (WHERE year(endDate) < 1000),                                                                                              
    COUNT(*) FILTER (WHERE year(endDate) > 3000)                                                                                               
FROM project WHERE endDate IS NOT NULL                                                                                                         
UNION ALL                                                                                                                                      
SELECT 'work.publicationDate', MIN(year(publicationDate)), MAX(year(publicationDate)),
    COUNT(*) FILTER (WHERE year(publicationDate) < 1000),                                                                                      
    COUNT(*) FILTER (WHERE year(publicationDate) > 3000)                                                                                       
FROM work WHERE publicationDate IS NOT NULL                                                                                           
"""
display(con.execute(q).df())
# Out:
#                     col  min_year  max_year  below_1000  above_3000
# 0     project.startDate         7      2125          18           0
# 1       project.endDate      1900      9999           0        3837
# 2  work.publicationDate         1      9999       14178        7198

# %% [markdown]
# ## Entity Publication

# %%
### Sample Rows

q = """ 
SELECT * FROM work
LIMIT 30
OFFSET 200000001
"""
display(con.execute(q).df())
# Out:
#                       id                                      openaireId  \
# 0    9415925887746482857  doi_________::cf42da24575e3e7a875f09b3c933cad2
# 1    6460611479800920237  doi_________::cf5356eb85fa4ae2b5d201947ee0054f
# 2    2280388855922583727  doi_________::cf5feed634d2f31b980fc774f9bddfdb
# 3    5181840263665961292  doi_________::cf61e7de02170b73d3f41f6e283c3a6f
# 4   14699259981232195458  doi_________::cf69e1c8daf2789f79c93e0b1a08842e
# ..                   ...                                             ...
# 25  17176906031274916464  doi_________::d0ec79280e351fa8b4a57b153177def6
# 26  16523867716069600531  doi_________::d1336dd444362f18103bcc9361205204
# 27   5853123668159886629  doi_________::d16432067ddfb2ff0744dfaf85741f13
# 28   6024906342842980676  doi_________::d17dfa615286b1b9f2c79767984e7ac0
# 29   6024929073675997777  doi_________::d1a0aa0d89d0cc2a03af6a3d68dde4f9
#
#                                                 title publicationDate  \
# 0   Proceedings of the First Annual Conference of ...      1971-04-01
# 1                                         EMS Insider      2011-09-01
# 2                                                Note      2009-03-01
# 3                                      Images et sons      2004-08-01
# 4   Решение задачи построения математической модел...      2021-10-04
# ..                                                ...             ...
# 25  Building modernization located in the conserva...      2022-05-16
# 26                                        Bücherschau      1937-05-01
# 27                                         Conclusion      2018-09-08
# 28                     Britain Can’t Be Anywhere Else      2002-01-01
# 29                            Country Report on Spain      2004-01-01
#
#                                         publisher openAccessColor  isGreen  \
# 0                               SAGE Publications            None    False
# 1                                     Elsevier BV            None    False
# 2                                   Franco Angeli            None    False
# 3                                           CAIRN            None    False
# 4                                  NPG Publishing            None    False
# ..                                            ...             ...      ...
# 25  Centrum Rzeczoznawstwa Budowlanego Sp z. o.o.            gold    False
# 26                         Walter de Gruyter GmbH            None    False
# 27              Presses de l'Université du Québec            None    False
# 28                          Palgrave Macmillan UK            None    False
# 29                     Springer Berlin Heidelberg            None    False
#
#     isInDiamondJournal  publiclyFunded  \
# 0                False           False
# 1                False           False
# 2                False           False
# 3                False           False
# 4                False           False
# ..                 ...             ...
# 25               False           False
# 26               False           False
# 27               False           False
# 28               False           False
# 29               False           False
#
#                                     language  \
# 0        {'code': 'eng', 'label': 'English'}
# 1        {'code': 'eng', 'label': 'English'}
# 2   {'code': 'und', 'label': 'Undetermined'}
# 3   {'code': 'und', 'label': 'Undetermined'}
# 4   {'code': 'und', 'label': 'Undetermined'}
# ..                                       ...
# 25  {'code': 'und', 'label': 'Undetermined'}
# 26       {'code': 'eng', 'label': 'English'}
# 27  {'code': 'und', 'label': 'Undetermined'}
# 28       {'code': 'eng', 'label': 'English'}
# 29  {'code': 'und', 'label': 'Undetermined'}
#
#                                       bestAccessRight  \
# 0   {'code': 'c_14cb', 'label': 'CLOSED', 'scheme'...
# 1   {'code': 'c_14cb', 'label': 'CLOSED', 'scheme'...
# 2                                                <NA>
# 3                                                <NA>
# 4   {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# ..                                                ...
# 25  {'code': 'c_abf2', 'label': 'OPEN', 'scheme': ...
# 26                                               <NA>
# 27                                               <NA>
# 28  {'code': 'c_14cb', 'label': 'CLOSED', 'scheme'...
# 29                                               <NA>
#
#                                               authors  \
# 0                                                <NA>
# 1                                                <NA>
# 2   [{'fullName': 'Antonio Maturo', 'name': 'Anton...
# 3                                                <NA>
# 4                                                <NA>
# ..                                                ...
# 25  [{'fullName': 'Maciej NIEDOSTATKIEWICZ', 'name...
# 26                                               <NA>
# 27                                               <NA>
# 28  [{'fullName': 'Charles Kennedy', 'name': 'Char...
# 29  [{'fullName': 'José Martädnez Soria', 'name': ...
#
#                                              subjects  \
# 0                                                <NA>
# 1                                                <NA>
# 2   [{'subject': {'scheme': 'FOS', 'value': '03 me...
# 3                                                <NA>
# 4                                                <NA>
# ..                                                ...
# 25  [{'subject': {'scheme': 'SDG', 'value': '11. S...
# 26                                               <NA>
# 27                                               <NA>
# 28                                               <NA>
# 29                                               <NA>
#
#                                          descriptions  \
# 0                                                <NA>
# 1                                                <NA>
# 2                                                <NA>
# 3                                                <NA>
# 4   [<jats:p>Актуальность выбранной темы обусловле...
# ..                                                ...
# 25  [<jats:p>The paper presents a description of t...
# 26                                               <NA>
# 27                                               <NA>
# 28                                               <NA>
# 29                                               <NA>
#
#                                                  pids  \
# 0   [{'scheme': 'doi', 'value': '10.1177/004728757...
# 1   [{'scheme': 'doi', 'value': '10.1016/s1081-450...
# 2   [{'scheme': 'doi', 'value': '10.3280/ses2009-0...
# 3   [{'scheme': 'doi', 'value': '10.3917/ving.083....
# 4   [{'scheme': 'doi', 'value': '10.24108/preprint...
# ..                                                ...
# 25  [{'scheme': 'doi', 'value': '10.37105/iboa.133'}]
# 26  [{'scheme': 'doi', 'value': '10.1515/zpch-1937...
# 27  [{'scheme': 'doi', 'value': '10.2307/j.ctv5j01...
# 28  [{'scheme': 'doi', 'value': '10.1007/978-1-137...
# 29  [{'scheme': 'doi', 'value': '10.1007/978-3-642...
#
#                                               sources formats  \
# 0                                          [Crossref]    <NA>
# 1                                          [Crossref]    <NA>
# 2                                          [Crossref]    <NA>
# 3                                          [Crossref]    <NA>
# 4                                          [Crossref]    <NA>
# ..                                                ...     ...
# 25                                         [Crossref]    <NA>
# 26                                         [Crossref]    <NA>
# 27  [Crossref, Fondements et pratiques de l'éducat...    <NA>
# 28  [Crossref, The Pro-European Reader ISBN: 97803...    <NA>
# 29  [Crossref, Beiträge zum ausländischen öffentli...    <NA>
#
#                                             instances  citationCount  \
# 0   [{'license': 'https://journals.sagepub.com/pag...            0.0
# 1   [{'license': 'Elsevier TDM', 'accessRight': {'...            0.0
# 2   [{'license': None, 'accessRight': None, 'type'...            0.0
# 3   [{'license': None, 'accessRight': None, 'type'...            0.0
# 4   [{'license': None, 'accessRight': None, 'type'...            0.0
# ..                                                ...            ...
# 25  [{'license': 'CC BY SA', 'accessRight': {'code...            0.0
# 26  [{'license': None, 'accessRight': None, 'type'...            0.0
# 27  [{'license': None, 'accessRight': None, 'type'...            0.0
# 28  [{'license': 'Springer TDM', 'accessRight': {'...            0.0
# 29  [{'license': None, 'accessRight': None, 'type'...            5.0
#
#        influence  views                                          container
# 0   2.583162e-09   <NA>  {'name': 'Travel Research Bulletin', 'issnPrin...
# 1   2.583162e-09   <NA>  {'name': 'EMS Insider', 'issnPrinted': '1081-4...
# 2   2.583162e-09   <NA>  {'name': 'SALUTE E SOCIETÀ', 'issnPrinted': '1...
# 3   2.583162e-09   <NA>  {'name': 'Vingtième Siècle. Revue d'histoire',...
# 4   2.583162e-09   <NA>                                               <NA>
# ..           ...    ...                                                ...
# 25  2.583162e-09   <NA>  {'name': 'Inżynieria Bezpieczeństwa Obiektów A...
# 26  2.583162e-09   <NA>  {'name': 'Zeitschrift für Physikalische Chemie...
# 27  2.583162e-09   <NA>                                               <NA>
# 28  2.583162e-09   <NA>                                               <NA>
# 29  3.533545e-09   <NA>                                               <NA>
#
# [30 rows x 22 columns]

# %%
### Descriptions distribution

q = """
SELECT 
    CASE 
        WHEN descriptions IS NULL THEN -1
        ELSE len(descriptions)
    END AS num_descriptions,
    COUNT(*) AS count,
    ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (), 2) AS percentage
FROM work
GROUP BY num_descriptions
ORDER BY num_descriptions
"""
display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[26], line 15
#       3 q = """
#       4 SELECT
#       5     CASE
#    (...)     13 ORDER BY num_descriptions
#      14 """
# ---> 15 display(con.execute(q).df())
#
# Error: KeyboardInterrupt: <EMPTY MESSAGE>
#
# At:
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/traitlets/traitlets.py(708): __set__
#   /tmp/ipykernel_2315519/237573814.py(15): <module>
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3670): run_code
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3610): run_ast_nodes
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3365): run_cell_async
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/async_helpers.py(128): _pseudo_sync_runner
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3153): _run_cell
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py(3098): run_cell
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/zmqshell.py(549): run_cell
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/ipkernel.py(449): do_execute
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py(778): execute_request
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/ipkernel.py(362): execute_request
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py(534): process_one
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/kernelbase.py(545): dispatch_queue
#   /home/lu72hip/.pyenv/versions/3.11.9/lib/python3.11/asyncio/events.py(84): _run
#   /home/lu72hip/.pyenv/versions/3.11.9/lib/python3.11/asyncio/base_events.py(1936): _run_once
#   /home/lu72hip/.pyenv/versions/3.11.9/lib/python3.11/asyncio/base_events.py(608): run_forever
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/tornado/platform/asyncio.py(205): start
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel/kernelapp.py(739): start
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/traitlets/config/application.py(1075): launch_instance
#   /home/lu72hip/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/ipykernel_launcher.py(18): <module>
#   <frozen runpy>(88): _run_code
#   <frozen runpy>(198): _run_module_as_main
#
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/DIGICHer/dh_pipeline/venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3691, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3689 except:
#    3690     if result is not None:
# -> 3691         result.error_in_exec = sys.exc_info()[1]
#    3692     self.showtraceback(running_compiled_code=True)
#    3693 else:
#
# KeyboardInterrupt:

# %%
### Check null count for each Column

q = """
SELECT 
    column_name,
    null_count,
    total_rows,
    ROUND(100.0 * null_count / total_rows, 2) as pct_null
FROM (
    SELECT 
        'id' as column_name,
        COUNT(*) FILTER (WHERE id IS NULL) as null_count,
        COUNT(*) as total_rows
    FROM work
    
    UNION ALL
    
    SELECT 'type', COUNT(*) FILTER (WHERE type IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'mainTitle', COUNT(*) FILTER (WHERE mainTitle IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'subTitle', COUNT(*) FILTER (WHERE subTitle IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'publicationDate', COUNT(*) FILTER (WHERE publicationDate IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'publisher', COUNT(*) FILTER (WHERE publisher IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'embargoEndDate', COUNT(*) FILTER (WHERE embargoEndDate IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'dateOfCollection', COUNT(*) FILTER (WHERE dateOfCollection IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'lastUpdateTimeStamp', COUNT(*) FILTER (WHERE lastUpdateTimeStamp IS NULL), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'openAccessColor', COUNT(*) FILTER (WHERE openAccessColor IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'isGreen', COUNT(*) FILTER (WHERE isGreen IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'isInDiamondJournal', COUNT(*) FILTER (WHERE isInDiamondJournal IS NULL), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'publiclyFunded', COUNT(*) FILTER (WHERE publiclyFunded IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'language', COUNT(*) FILTER (WHERE language IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'bestAccessRight', COUNT(*) FILTER (WHERE bestAccessRight IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'authors', COUNT(*) FILTER (WHERE authors IS NULL OR len(authors) = 0), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'countries', COUNT(*) FILTER (WHERE countries IS NULL OR len(countries) = 0), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'subjects', COUNT(*) FILTER (WHERE subjects IS NULL OR len(subjects) = 0), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'descriptions', COUNT(*) FILTER (WHERE descriptions IS NULL OR len(descriptions) = 0), COUNT(*) FROM work
    UNION ALL
    SELECT 'originalIds', COUNT(*) FILTER (WHERE originalIds IS NULL OR len(originalIds) = 0), COUNT(*) FROM work
    UNION ALL
    SELECT 'pids', COUNT(*) FILTER (WHERE pids IS NULL OR len(pids) = 0), COUNT(*) FROM work
    UNION ALL
    SELECT 'sources', COUNT(*) FILTER (WHERE sources IS NULL OR len(sources) = 0), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'formats', COUNT(*) FILTER (WHERE formats IS NULL OR len(formats) = 0), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'contributors', COUNT(*) FILTER (WHERE contributors IS NULL OR len(contributors) = 0), COUNT(*) FROM work
    UNION ALL
    SELECT 'coverages', COUNT(*) FILTER (WHERE coverages IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'container', COUNT(*) FILTER (WHERE container IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'instances', COUNT(*) FILTER (WHERE instances IS NULL OR len(instances) = 0), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'indicators', COUNT(*) FILTER (WHERE indicators IS NULL), COUNT(*) FROM work
    UNION ALL
    SELECT 'documentationUrls', COUNT(*) FILTER (WHERE documentationUrls IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'codeRepositoryUrl', COUNT(*) FILTER (WHERE codeRepositoryUrl IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'programmingLanguage', COUNT(*) FILTER (WHERE programmingLanguage IS NULL), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'contactPeople', COUNT(*) FILTER (WHERE contactPeople IS NULL), COUNT(*) FROM work
    UNION ALL
    -- SELECT 'contactGroups', COUNT(*) FILTER (WHERE contactGroups IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'tools', COUNT(*) FILTER (WHERE tools IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'size', COUNT(*) FILTER (WHERE size IS NULL), COUNT(*) FROM work
    -- UNION ALL
    -- SELECT 'version', COUNT(*) FILTER (WHERE version IS NULL), COUNT(*) FROM work
    -- UNION ALL
    SELECT 'geoLocations', COUNT(*) FILTER (WHERE geoLocations IS NULL), COUNT(*) FROM work
)
ORDER BY pct_null DESC
"""

display(con.execute(q).df())

# %% [markdown]
# ## Entity relation
#
# * Do i need to precompute Works and Projects impact, what is already there
# * Remove all relations.type? == product where is not project??????

# %%
q = """ 
SELECT * FROM relation LIMIT 3
"""
display(con.execute(q).df())
# Out:
#                 source sourceType                target    targetType  \
# 0  7394781489291612645    product  18150248833008221797  organization
# 1  4611416004720601728    product  18150248833008221797  organization
# 2  1943491943382936829    product  18150248833008221797  organization
#
#                                              relType  \
# 0  {'name': 'hasAuthorInstitution', 'type': 'affi...
# 1  {'name': 'hasAuthorInstitution', 'type': 'affi...
# 2  {'name': 'hasAuthorInstitution', 'type': 'affi...
#
#                                           provenance  validated
# 0  {'provenance': 'Inferred by OpenAIRE', 'trust'...      False
# 1  {'provenance': 'Inferred by OpenAIRE', 'trust'...      False
# 2  {'provenance': 'Inferred by OpenAIRE', 'trust'...      False

# %%
### Check all unique sourceType and targetType values

q = """
SELECT 
    sourceType,
    targetType,
    COUNT(*) as count,
    ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (), 2) as pct
FROM relation
GROUP BY sourceType, targetType
ORDER BY count DESC
"""
display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#      sourceType    targetType      count    pct
# 0       product  organization  268313783  47.73
# 1  organization       product  268313783  47.73
# 2       project       product    8220760   1.46
# 3       product       project    8220760   1.46
# 4       project  organization    4568712   0.81
# 5  organization       project    4568712   0.81

# %%
### Check ID prefixes of products in relations

q = """
SELECT 
    SUBSTRING(source, 1, 12) as id_prefix,
    COUNT(*) as count,
    ROUND(COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (), 2) as pct
FROM relation
WHERE sourceType = 'product'
GROUP BY id_prefix
ORDER BY count DESC
LIMIT 20
"""
display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#        id_prefix      count    pct
# 0   doi_dedup___  223717794  80.90
# 1   doi_________   22320185   8.07
# 2   dedup_wf_002   13247272   4.79
# 3   pmid________    2155889   0.78
# 4   pmid_dedup__    1136784   0.41
# 5   od_______177     580252   0.21
# 6   a9ac50f576aa     474983   0.17
# 7   od_____10049     334374   0.12
# 8   r3c4b2081b22     259387   0.09
# 9   od______3686     222980   0.08
# 10  od______2186     209820   0.08
# 11  od______4168     188987   0.07
# 12  od______9730     165850   0.06
# 13  od______9405     144576   0.05
# 14  researchfi__     143272   0.05
# 15  doajarticles     138166   0.05
# 16  od______1594     132836   0.05
# 17  od_______970     130372   0.05
# 18  od______4094     127509   0.05
# 19  od______4596     123917   0.04

# %% [markdown]
# ## Impact Metrics

# %%
### Question: What impact metrics exist for publications?
# Result:
# total_publications	has_indicators	has_citationImpact	has_usageCounts	avg_citations	avg_downloads	avg_views
# 205841448	            200351379	    200347669	        3600953	        10.627821	    57.977084	    35.391892
# Results without null:
# total_publications	has_indicators	has_citationImpact	has_usageCounts	avg_citations	avg_downloads	avg_views
# 205841448	            200351379	    200351379	        200351379	    10.627821	    57.977084	    35.391892


q = """
SELECT
    COUNT(*) AS total_publications,
    COUNT(indicators) AS has_indicators,
    COUNT(indicators->'citationImpact') AS has_citationImpact,
    COUNT(indicators->'usageCounts') AS has_usageCounts,
    AVG(CAST(NULLIF(indicators->'citationImpact'->>'citationCount','') AS INTEGER)) AS avg_citations,
    AVG(CAST(NULLIF(indicators->'usageCounts'->>'downloads','') AS INTEGER)) AS avg_downloads,
    AVG(CAST(NULLIF(indicators->'usageCounts'->>'views','') AS INTEGER)) AS avg_views
FROM work
"""

display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#    total_publications  has_indicators  has_citationImpact  has_usageCounts  \
# 0           205841448       200351379           200351379        200351379
#
#    avg_citations  avg_downloads  avg_views
# 0      10.627821      57.977084  35.391892

# %%
### Top 3 cited papers

q = """
SELECT
    id,
    mainTitle,
    CAST(NULLIF(indicators->'citationImpact'->>'citationCount','') AS INTEGER) AS citations
FROM work
WHERE indicators->'citationImpact'->>'citationCount' IS NOT NULL
ORDER BY citations DESC
LIMIT 3
"""

display(con.execute(q).df())
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#                                                id  \
# 0  doi_dedup___::6013564d557628905abf3c0f70e51675
# 1  doi_dedup___::ee253ec27e28ed6b0df7da99c853917f
# 2  doi_dedup___::ec319731a12c0b83e5d4bf781693cdac
#
#                                            mainTitle  citations
# 0  PROTEIN MEASUREMENT WITH THE FOLIN PHENOL REAGENT     340187
# 1  Cleavage of Structural Proteins during the Ass...     262820
# 2  A Rapid and Sensitive Method for the Quantitat...     248877

# %%
### Check indicators struct: column paths for citationCount, influence, views
# Confirms staging.py extraction: indicators.citationImpact.citationCount / .influence / indicators.usageCounts.views

q = """                                                                                                                                        
SELECT                                                                                                                                         
    COUNT(*)                                            AS total,                                                                              
    COUNT(indicators)                                   AS has_indicators,                                                                     
    COUNT(indicators.citationImpact.citationCount)      AS has_citationCount,                                                                  
    COUNT(indicators.citationImpact.influence)          AS has_influence,                                                                      
    COUNT(indicators.usageCounts.views)                 AS has_views,                                                                          
    AVG(indicators.citationImpact.citationCount)        AS avg_citationCount,                                                                  
    AVG(indicators.citationImpact.influence)            AS avg_influence,                                                                      
    AVG(indicators.usageCounts.views)                   AS avg_views                                                                           
FROM work                                                                                                                               
"""                                                                                                                                            
display(con.execute(q).df())
# Out:
#        total  has_indicators  has_citationCount  has_influence  has_views  \
# 0  205841448       200351379          200347669      200347669    3600953
#
#    avg_citationCount  avg_influence  avg_views
# 0          10.627821   3.496346e-09  35.391892

# %% [markdown]
# # Connecting to Cordis

# %%
# Check Project ID prefixes
q_proj_ids = """
SELECT 
    split_part(id, '::', 1) as prefix, 
    count(*) as cnt
FROM project
GROUP BY 1
ORDER BY cnt DESC;
"""
display(con.execute(q_proj_ids).df())

# Check Organization ID prefixes
q_org_ids = """
SELECT 
    split_part(id, '::', 1) as prefix, 
    count(*) as cnt
FROM organization
GROUP BY 1
ORDER BY cnt DESC;
"""
display(con.execute(q_org_ids).df())
# Out:
#            prefix      cnt
# 0    nih_________  2277712
# 1    nsf_________   592489
# 2    ukri________   175092
# 3    fct_________    94440
# 4    snsf________    90082
# ..            ...      ...
# 264  501100010808        1
# 265  501100000274        1
# 266  nserc_______        1
# 267  501100001589        1
# 268  501100001592        1
#
# [269 rows x 2 columns]
#          prefix     cnt
# 0  pending_org_  345425
# 1  openorgs____  102726
# 2  edtech______       4
# 3  ror_________       3
# 4  ukri________       2
# 5  fairsharing_       1

# %%
### Count all EC Projects: 115447
# From 155 979 (with archived content) officially on cordis

q = """ 
SELECT 
    count(*)
FROM project
WHERE list_transform(fundings, x -> x.shortName).list_contains('EC');
"""
display(con.execute(q).df())
# Out:
#    count_star()
# 0        115447

# %%
### Breakdown of EC Projects by Programme
q = """
SELECT 
    f.fundingStream, 
    count(*) as project_count
FROM project, 
     UNNEST(fundings) as f
WHERE f.shortName = 'EC'
GROUP BY 1
ORDER BY project_count DESC;
"""
display(con.execute(q).df())
